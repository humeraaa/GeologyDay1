# %% [markdown]
# #Installation gdal

# %%
# !apt install gdal-bin python-gdal python3-gdal

# %%
import gdal

# %% [markdown]
# #Installation Cartropy

# %%
# !apt-get install libproj-dev proj-data proj-bin
# !apt-get install libgeos-dev
# !pip install cython
# !pip install cartopy
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# proj-bin is already the newest version (4.9.3-2).
# proj-bin set to manually installed.
# proj-data is already the newest version (4.9.3-2).
# proj-data set to manually installed.
# The following NEW packages will be installed:
#   libproj-dev
# 0 upgraded, 1 newly installed, 0 to remove and 5 not upgraded.
# Need to get 199 kB of archives.
# After this operation, 1,110 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libproj-dev amd64 4.9.3-2 [199 kB]
# Fetched 199 kB in 1s (370 kB/s)
# Selecting previously unselected package libproj-dev:amd64.
# (Reading database ... 24222 files and directories currently installed.)
# Preparing to unpack .../libproj-dev_4.9.3-2_amd64.deb ...
# Unpacking libproj-dev:amd64 (4.9.3-2) ...
# Setting up libproj-dev:amd64 (4.9.3-2) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   libgdal-doc
# The following NEW packages will be installed:
#   libgeos-dev
# 0 upgraded, 1 newly installed, 0 to remove and 5 not upgraded.
# Need to get 73.1 kB of archives.
# After this operation, 486 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgeos-dev amd64 3.6.2-1build2 [73.1 kB]
# Fetched 73.1 kB in 0s (177 kB/s)
# Selecting previously unselected package libgeos-dev.
# (Reading database ... 24239 files and directories currently installed.)
# Preparing to unpack .../libgeos-dev_3.6.2-1build2_amd64.deb ...
# Unpacking libgeos-dev (3.6.2-1build2) ...
# Setting up libgeos-dev (3.6.2-1build2) ...
# Collecting cython
#   Downloading https://files.pythonhosted.org/packages/64/3f/cac281f3f019b825bbc03fa8cb7eb03d9c355f4aa9eef978279a4966cb21/Cython-0.29-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#     100% |████████████████████████████████| 2.1MB 1.8MB/s
# Installing collected packages: cython
# Successfully installed cython-0.29
# Collecting cartopy
#   Downloading https://files.pythonhosted.org/packages/e5/92/fe8838fa8158931906dfc4f16c5c1436b3dd2daf83592645b179581403ad/Cartopy-0.17.0.tar.gz (8.9MB)
#     100% |████████████████████████████████| 8.9MB 3.6MB/s
# done
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.6/dist-packages (from cartopy) (1.14.6)
# Collecting shapely>=1.5.6 (from cartopy)
#   Downloading https://files.pythonhosted.org/packages/38/b6/b53f19062afd49bb5abd049aeed36f13bf8d57ef8f3fa07a5203531a0252/Shapely-1.6.4.post2-cp36-cp36m-manylinux1_x86_64.whl (1.5MB)
#     100% |████████████████████████████████| 1.5MB 14.3MB/s
# Collecting pyshp>=1.1.4 (from cartopy)
#   Downloading https://files.pythonhosted.org/packages/08/3e/3bda7dfdbee0d7a22d38443f5cc8d154ff6d4701e615f4c07bf1ed003563/pyshp-2.0.1.tar.gz (214kB)
#     100% |████████████████████████████████| 215kB 27.5MB/s
# Requirement already satisfied: six>=1.3.0 in /usr/local/lib/python3.6/dist-packages (from cartopy) (1.11.0)
# Requirement already satisfied: setuptools>=0.7.2 in /usr/local/lib/python3.6/dist-packages (from cartopy) (40.6.2)
# Building wheels for collected packages: cartopy, pyshp
# done
#   Stored in directory: /root/.cache/pip/wheels/cd/cf/40/539f798f94e921e94fd376a5f9d213a6febe77754c0b187c73
# done
#   Stored in directory: /root/.cache/pip/wheels/cc/e8/7c/f00fc95ae2a16ed41be9defdd647213a334fd12e03b1452c26
# Successfully built cartopy pyshp
# Installing collected packages: shapely, pyshp, cartopy
# Successfully installed cartopy-0.17.0 pyshp-2.0.1 shapely-1.6.4.post2

# %%
import cartopy

# %% [markdown]
# #Installation GeoPandas

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading https://files.pythonhosted.org/packages/24/11/d77c157c16909bd77557d00798b05a5b6615ed60acb5900fbe6a65d35e93/geopandas-0.4.0-py2.py3-none-any.whl (899kB)
#     100% |████████████████████████████████| 901kB 18.5MB/s
# Requirement already satisfied: shapely in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.6.4.post2)
# Collecting fiona (from geopandas)
#   Downloading https://files.pythonhosted.org/packages/bb/7b/3378b9637dbe7aeceb33a53a546ba34d1089796321ce40cda13528f8d388/Fiona-1.8.1-cp36-cp36m-manylinux1_x86_64.whl (17.9MB)
#     100% |████████████████████████████████| 17.9MB 2.3MB/s
# Collecting pyproj (from geopandas)
#   Downloading https://files.pythonhosted.org/packages/29/72/5c1888c4948a0c7b736d10e0f0f69966e7c0874a660222ed0a2c2c6daa9f/pyproj-1.9.5.1.tar.gz (4.4MB)
#     100% |████████████████████████████████| 4.4MB 6.1MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from geopandas) (0.22.0)
# Collecting cligj>=0.5 (from fiona->geopandas)
#   Downloading https://files.pythonhosted.org/packages/e4/be/30a58b4b0733850280d01f8bd132591b4668ed5c7046761098d665ac2174/cligj-0.5.0-py3-none-any.whl
# Collecting munch (from fiona->geopandas)
#   Downloading https://files.pythonhosted.org/packages/68/f4/260ec98ea840757a0da09e0ed8135333d59b8dfebe9752a365b04857660a/munch-2.3.2.tar.gz
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (18.2.0)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.11.0)
# Collecting click-plugins>=1.0 (from fiona->geopandas)
#   Downloading https://files.pythonhosted.org/packages/95/dd/fef84cf1678418f241ef542c0288bdf215bdd3e35f1fe03dc5223a2e80ba/click_plugins-1.0.4-py2.py3-none-any.whl
# Collecting click<8,>=4.0 (from fiona->geopandas)
#   Downloading https://files.pythonhosted.org/packages/fa/37/45185cb5abbc30d7257104c434fe0b07e5a195a6847506c074527aa599ec/Click-7.0-py2.py3-none-any.whl (81kB)
#     100% |████████████████████████████████| 81kB 23.4MB/s
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas->geopandas) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->geopandas) (2018.7)
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from pandas->geopandas) (1.14.6)
# Building wheels for collected packages: pyproj, munch
# done
#   Stored in directory: /root/.cache/pip/wheels/89/77/ec/a537585d1022dafde0317dd19d33c4a30d4ee61e19f25ebd8e
# done
#   Stored in directory: /root/.cache/pip/wheels/db/bf/bc/06a3e1bfe0ab27d2e720ceb3cff3159398d92644c0cec2c125
# Successfully built pyproj munch
# Installing collected packages: click, cligj, munch, click-plugins, fiona, pyproj, geopandas
# Successfully installed click-7.0 click-plugins-1.0.4 cligj-0.5.0 fiona-1.8.1 geopandas-0.4.0 munch-2.3.2 pyproj-1.9.5.1

# %%
import geopandas

# %% [markdown]
# #File Read Write

# %%
ls
# Out:
# sample_data/

# %%
from google.colab import files
files.upload() #Choose all the files which you want to import at once
# Out:
#      <input type="file" id="files-7c7573c5-ad81-457b-b8f0-43f6d109b350" name="files[]" multiple disabled />
#      <output id="result-7c7573c5-ad81-457b-b8f0-43f6d109b350">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
ls
# Out:
# gdal/  gdal.zip  sample_data/

# %% [markdown]
# #Zip FIles

# %%
files.upload() #Now just select Zip files
# Out:
#      <input type="file" id="files-03b2b383-3eff-47cf-b856-6ce48b3dfa0f" name="files[]" multiple disabled />
#      <output id="result-03b2b383-3eff-47cf-b856-6ce48b3dfa0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
from zipfile import ZipFile

gdal = ZipFile('gdal.zip','r')

# %%
gdal.extractall()

# %%
ls
# Out:
# gdal/  gdal.zip  sample_data/
